# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("tips.csv")
df.head
df.columns
df.tail()
df.describe()
sns.load_dataset("tips")
sns.boxplot(df["total_bill"]).set_title(" ")
sns.boxplot(x=df['tip'],y=df['day'])
sns.displot(df['sex'],kde=False)
sns.displot(df['tip'],kde=False)
sns.set_theme()
sns.lmplot(x='tip',y='total_bill',data=df)
# Out:
# C:\Users\Aarti A Chavan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
